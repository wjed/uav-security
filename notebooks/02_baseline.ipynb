# %% [markdown]
# # 02 — Centralized Baseline Models
#
# **Owner: Group A** — Will Jedrzejczak, Cole Walther, Dilpreet Gill
# IT 445 / IT 499 Capstone · James Madison University · Summer 2026

# %% [markdown]
# ## Section 1 — Preprocessing and Setup
#
# Run `src/data/preprocessor.py` to produce scaled train/val/test splits.
# Confirm class distributions are preserved after stratified splitting.
# Load binary labels (Normal vs. Attack) and multiclass labels (5 classes) for both experiments.
# Set random seed 42 for reproducibility.

# %% [markdown]
# ## Section 2 — Logistic Regression Baseline
#
# Train `LogisticRegressionModel` (binary and multiclass) using `src/models/logistic_regression.py`.
# Evaluate on val and test splits.
# Report: accuracy, per-class F1, confusion matrix, FPR, FNR.
# This establishes the simplest possible linear decision boundary as a lower-bound reference.

# %% [markdown]
# ## Section 3 — Random Forest Baseline
#
# Train `RandomForestModel` (binary and multiclass) using `src/models/random_forest.py`.
# Report the same metrics as Section 2.
# Plot the top-10 most important features from `get_feature_importances()`.
# Random Forest typically performs well on tabular sensor data and sets a strong non-FL upper bound.

# %% [markdown]
# ## Section 4 — DNN Baseline and Model Comparison
#
# Train `DNNClassifier` (hidden sizes [128, 64, 32]) using `src/models/dnn.py`.
# Plot training and validation loss curves across epochs.
# Produce a final comparison table: Logistic Regression vs. Random Forest vs. DNN
# on all five metrics for both binary and multiclass tasks.
# The DNN baseline is the centralized ceiling the FL pipeline will be compared against in notebook 03.
