# %% [markdown]
# # 03 — Federated Learning Experiments
#
# **Owner: Group A** — Will Jedrzejczak, Cole Walther, Dilpreet Gill
# IT 445 / IT 499 Capstone · James Madison University · Summer 2026

# %% [markdown]
# ## Section 1 — FL Setup and Client Data Partitioning
#
# Configure the Flower simulation: 5 UAV clients, 20 FL rounds, 3 local epochs, lr=0.001.
# Run `src/data/partitioner.py` in both IID and non-IID (Dirichlet alpha=0.5) modes.
# Visualize the resulting per-client class distributions before launching any FL experiments.
# Confirm all clients have enough samples and no degenerate splits exist.

# %% [markdown]
# ## Section 2 — FedAvg Experiments
#
# Run `src/federated/run_fl.py` with `--strategy fedavg` under both IID and non-IID partitioning.
# Log global model accuracy and loss per round.
# Plot per-round accuracy curve for both partitioning strategies.
# Compare final test accuracy and F1 against the centralized DNN baseline from notebook 02.

# %% [markdown]
# ## Section 3 — FedProx Experiments and Comparison
#
# Run `src/federated/run_fl.py` with `--strategy fedprox` (proximal_mu=0.1) under non-IID partitioning.
# FedProx constrains local updates, reducing client drift on heterogeneous UAV data.
# Overlay FedAvg vs. FedProx per-round accuracy curves on the same plot.
# Report final metrics side-by-side: accuracy, macro-F1, FPR, FNR.

# %% [markdown]
# ## Section 4 — Prediction Export and Handoff to Group B
#
# Export final test-set predictions from the best FL model to `results/fl_predictions.csv`.
# Columns: node_id, predicted_class, confidence_score.
# This file is the primary handoff artifact to Group B for `src/mitigation/rules.py`.
# Document any caveats: simulation-to-real gap, LEACH-to-UAV feature mismatch,
# FL poisoning as a residual risk not addressed in this implementation.
